# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = pd.read_csv('data/train.csv')

# %%
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
y_train = dataset.iloc[:, -1].values
y_train
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %%
X_train = dataset.iloc[:, 1:-1]
X_train.shape
# Out:
# (1460, 79)

# %%
X_train.isna().sum().loc[X_train.isna().sum() > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ### Dealing with missing values

# %%
X_train['LotFrontage'].head()
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# Name: LotFrontage, dtype: float64

# %%
X_train['LotFrontage'] = X_train['LotFrontage'].fillna(X_train['LotFrontage'].mean())

# %%
X_train.groupby('Alley').count()
# Out:
#        MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# Alley
# Grvl           50        50           50       50      50        50
# Pave           41        41           41       41      41        41
#
#        LandContour  Utilities  LotConfig  LandSlope      ...        \
# Alley                                                    ...
# Grvl            50         50         50         50      ...
# Pave            41         41         41         41      ...
#
#        ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  MoSold  \
# Alley
# Grvl            50        50       0     14            4       50      50
# Pave            41        41       0      4            0       41      41
#
#        YrSold  SaleType  SaleCondition
# Alley
# Grvl       50        50             50
# Pave       41        41             41
#
# [2 rows x 78 columns]

# %%
X_train['Alley'].fillna('None', inplace=True)

# %%
print(X_train['MasVnrType'].head())
X_train.groupby('MasVnrType').count()
# Out:
# 0    BrkFace
# 1       None
# 2    BrkFace
# 3       None
# 4    BrkFace
# Name: MasVnrType, dtype: object
#             MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# MasVnrType
# BrkCmn              15        15           15       15      15     15
# BrkFace            445       445          445      445     445    445
# None               864       864          864      864     864    864
# Stone              128       128          128      128     128    128
#
#             LotShape  LandContour  Utilities  LotConfig      ...        \
# MasVnrType                                                   ...
# BrkCmn            15           15         15         15      ...
# BrkFace          445          445        445        445      ...
# None             864          864        864        864      ...
# Stone            128          128        128        128      ...
#
#             ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# MasVnrType
# ...

# %%
X_train['MasVnrType'] = X_train['MasVnrType'].fillna('None')

# %%
X_train.groupby('MasVnrType').count()
# Out:
#             MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# MasVnrType
# BrkCmn              15        15           15       15      15     15
# BrkFace            445       445          445      445     445    445
# None               872       872          872      872     872    872
# Stone              128       128          128      128     128    128
#
#             LotShape  LandContour  Utilities  LotConfig      ...        \
# MasVnrType                                                   ...
# BrkCmn            15           15         15         15      ...
# BrkFace          445          445        445        445      ...
# None             872          872        872        872      ...
# Stone            128          128        128        128      ...
#
#             ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# MasVnrType
# BrkCmn               15        15       0      7            2       15
# ...

# %%
X_train['MasVnrArea'].head()
# Out:
# 0    196.0
# 1      0.0
# 2    162.0
# 3      0.0
# 4    350.0
# Name: MasVnrArea, dtype: float64

# %%
X_train['MasVnrArea'].fillna(0, inplace=True)

# %%
X_train.loc[:, ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']].head(20)
# Out:
#    BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 0        Gd       TA           No          GLQ          Unf
# 1        Gd       TA           Gd          ALQ          Unf
# 2        Gd       TA           Mn          GLQ          Unf
# 3        TA       Gd           No          ALQ          Unf
# 4        Gd       TA           Av          GLQ          Unf
# 5        Gd       TA           No          GLQ          Unf
# 6        Ex       TA           Av          GLQ          Unf
# 7        Gd       TA           Mn          ALQ          BLQ
# 8        TA       TA           No          Unf          Unf
# 9        TA       TA           No          GLQ          Unf
# 10       TA       TA           No          Rec          Unf
# 11       Ex       TA           No          GLQ          Unf
# 12       TA       TA           No          ALQ          Unf
# 13       Gd       TA           Av          Unf          Unf
# 14       TA       TA           No          BLQ          Unf
# ...

# %%
X_train['BsmtQual'].fillna('None', inplace=True)
X_train['BsmtCond'].fillna('None', inplace=True)
X_train['BsmtExposure'].fillna('None', inplace=True)
X_train['BsmtFinType1'].fillna('None', inplace=True)
X_train['BsmtFinType2'].fillna('None', inplace=True)

# %%
X_train.shape
# Out:
# (1460, 79)

# %%
X_train = X_train.loc[X_train['Electrical'].isna() == False]
X_train.shape
# Out:
# (1459, 79)

# %%
X_train['FireplaceQu'].head(10)
# Out:
# 0    NaN
# 1     TA
# 2     TA
# 3     Gd
# 4     TA
# 5    NaN
# 6     Gd
# 7     TA
# 8     TA
# 9     TA
# Name: FireplaceQu, dtype: object

# %%
X_train['FireplaceQu'].fillna('None', inplace=True)

# %%
X_train.loc[:, ['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond']].head() # 40
# Out:
#   GarageType  GarageYrBlt GarageFinish GarageQual GarageCond
# 0     Attchd       2003.0          RFn         TA         TA
# 1     Attchd       1976.0          RFn         TA         TA
# 2     Attchd       2001.0          RFn         TA         TA
# 3     Detchd       1998.0          Unf         TA         TA
# 4     Attchd       2000.0          RFn         TA         TA

# %%
X_train['GarageType'].fillna('None', inplace=True)
X_train['GarageYrBlt'].fillna('None', inplace=True)
X_train['GarageFinish'].fillna('None', inplace=True)
X_train['GarageQual'].fillna('None', inplace=True)
X_train['GarageCond'].fillna('None', inplace=True)

# %%
print(X_train.loc[:, ['PoolQC', 'Fence', 'MiscFeature']].head())
print(X_train['PoolQC'].unique())
print(X_train['Fence'].unique())
print(X_train['MiscFeature'].unique())
# Out:
#   PoolQC Fence MiscFeature
# 0    NaN   NaN         NaN
# 1    NaN   NaN         NaN
# 2    NaN   NaN         NaN
# 3    NaN   NaN         NaN
# 4    NaN   NaN         NaN
# [nan 'Ex' 'Fa' 'Gd']
# [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %%
X_train['PoolQC'].fillna('None', inplace=True)
X_train['Fence'].fillna('None', inplace=True)
X_train['MiscFeature'].fillna('None', inplace=True)

# %%
X_train.isna().sum().loc[X_train.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Outliers!!!

# %% [markdown]
# ### Feature Engineering!!

# %%
X_sc = MinMaxScaler()
transformed_npa = X_sc.fit_transform(X_train[list(X_train.describe().columns)])

# %%
X_train[list(X_train.describe().columns)].head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0           60    65.000000     8450            7            5       2003
# 1           20    80.000000     9600            6            8       1976
# 2           60    68.000000    11250            7            5       2001
# 3           70    60.000000     9550            7            5       1915
# 4           60    84.000000    14260            8            5       2000
# 5           50    85.000000    14115            5            5       1993
# 6           20    75.000000    10084            8            5       2004
# 7           60    70.049958    10382            7            6       1973
# 8           50    51.000000     6120            7            5       1931
# 9          190    50.000000     7420            5            6       1939
# 10          20    70.000000    11200            5            5       1965
# 11          60    85.000000    11924            9            5       2005
# ...

# %%
transformed_df = pd.DataFrame(transformed_npa)
transformed_df.columns = X_train.describe().columns
X_train[list(X_train.describe().columns)] = transformed_df
X_train[list(X_train.describe().columns)].head()
# Out:
#     MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0     0.235294       RL     0.150685  0.033420   Pave  None      Reg
# 1     0.000000       RL     0.202055  0.038795   Pave  None      Reg
# 2     0.235294       RL     0.160959  0.046507   Pave  None      IR1
# 3     0.294118       RL     0.133562  0.038561   Pave  None      IR1
# 4     0.235294       RL     0.215753  0.060576   Pave  None      IR1
# 5     0.176471       RL     0.219178  0.059899   Pave  None      IR1
# 6     0.000000       RL     0.184932  0.041057   Pave  None      Reg
# 7     0.235294       RL     0.167979  0.042450   Pave  None      IR1
# 8     0.176471       RM     0.102740  0.022529   Pave  None      Reg
# 9     1.000000       RL     0.099315  0.028605   Pave  None      Reg
# 10    0.000000       RL     0.167808  0.046274   Pave  None      Reg
# 11    0.235294       RL     0.219178  0.049658   Pave  None      IR1
# 12    0.000000       RL     0.167979  0.054537   Pave  None      IR2
# ...

# %%
pd.get_dummies(X_train).shape

# %%
X_train.iloc[:, 70:].describe()
# Out:
#           PoolArea       MiscVal       MoSold       YrSold
# count  1459.000000   1459.000000  1459.000000  1459.000000
# mean      2.760795     43.518849     6.322824  2007.815627
# std      40.191018    496.291826     2.704331     1.328542
# min       0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000      0.000000     8.000000  2009.000000
# max     738.000000  15500.000000    12.000000  2010.000000

# %%
normalizers = {}
def normalize_column(X, column: str):
    df = X.loc[:, [column]]
    if column in normalizers.keys():
        normalizer = normalizers[column]
    else:
        normalizer = MinMaxScaler()
        normalizer.fit(df)
        normalizers[column] = normalizer
    np_scaled = normalizer.transform(df)
    X[column] = pd.DataFrame(np_scaled)[0]

for column in list(X_train.describe().columns):
    normalize_column(X_train, column)
X_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0    0.235294       RL     0.150685  0.033420   Pave  None      Reg
# 1    0.000000       RL     0.202055  0.038795   Pave  None      Reg
# 2    0.235294       RL     0.160959  0.046507   Pave  None      IR1
# 3    0.294118       RL     0.133562  0.038561   Pave  None      IR1
# 4    0.235294       RL     0.215753  0.060576   Pave  None      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...               0.0      0.0   None
# 1         Lvl    AllPub       FR2      ...               0.0      0.0   None
# 2         Lvl    AllPub    Inside      ...               0.0      0.0   None
# 3         Lvl    AllPub    Corner      ...               0.0      0.0   None
# 4         Lvl    AllPub       FR2      ...               0.0      0.0   None
#
#   Fence MiscFeature MiscVal    MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
normalizers
# Out:
# {'1stFlrSF': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  '2ndFlrSF': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  '3SsnPorch': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BedroomAbvGr': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BsmtFinSF1': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BsmtFinSF2': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BsmtFullBath': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BsmtHalfBath': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'BsmtUnfSF': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'EnclosedPorch': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'Fireplaces': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'FullBath': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'GarageArea': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'GarageCars': MinMaxScaler(copy=True, feature_range=(0, 1)),
#  'GrLivArea': MinMaxScaler(copy=True, feature_range=(0, 1)),
# ...

# %%
X_train_back.isna().sum().loc[X_train_back.isna().sum() > 0]
# Out:
# MSSubClass       1
# LotFrontage      1
# LotArea          1
# OverallQual      1
# OverallCond      1
# YearBuilt        1
# YearRemodAdd     1
# MasVnrArea       1
# BsmtFinSF1       1
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# 1stFlrSF         1
# 2ndFlrSF         1
# LowQualFinSF     1
# GrLivArea        1
# BsmtFullBath     1
# BsmtHalfBath     1
# FullBath         1
# HalfBath         1
# BedroomAbvGr     1
# KitchenAbvGr     1
# TotRmsAbvGrd     1
# Fireplaces       1
# GarageCars       1
# GarageArea       1
# WoodDeckSF       1
# OpenPorchSF      1
# EnclosedPorch    1
# 3SsnPorch        1
# ScreenPorch      1
# PoolArea         1
# MiscVal          1
# MoSold           1
# YrSold           1
# dtype: int64

# %%
df = X_train.loc[:, ['YrSold']]
min_max_scaler = MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df)
X_train_back['YrSold'] = pd.DataFrame(np_scaled)[0]
X_train_back['YrSold'].head()
# Out:
# 0    0.50
# 1    0.25
# 2    0.50
# 3    0.00
# 4    0.50
# Name: YrSold, dtype: float64

# %%
col_npa = col.values

# normalizer = MinMaxScaler()
# normalizer.fit(col_npa)
# col_npa = normalizer.transform(col_npa)
print(col_npa.shape)
col_sr = pd.Series(col_npa)
print(col_npa[:10])
print(col_sr.head(10))
# Out:
# (1459,)
# [2008 2007 2008 2006 2008 2009 2007 2009 2008 2008]
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
# 5    2009
# 6    2007
# 7    2009
# 8    2008
# 9    2008
# dtype: int64
