# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import itertools

# %%
dataset = pd.read_csv('data/train.csv')
dataset_test = pd.read_csv('data/test.csv')

# %%
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
dataset_test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# min       1.000000  1879.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1953.000000   1963.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1992.000000     0.000000   350.500000
# 75%       6.000000  2001.000000   2004.000000   164.000000   753.500000
# max       9.000000  2010.000000   2010.000000  1290.000000  4010.000000
#
#           ...        GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count     ...       1458.000000  1459.000000  1459.000000    1459.000000
# mean      ...        472.768861    93.174777    48.313914      24.243317
# std       ...        217.048611   127.744882    68.883364      67.227765
# min       ...          0.000000     0.000000     0.000000       0.000000
# 25%       ...        318.000000     0.000000     0.000000       0.000000
# 50%       ...        480.000000     0.000000    28.000000       0.000000
# 75%       ...        576.000000   168.000000    72.000000       0.000000
# max       ...       1488.000000  1424.000000   742.000000    1012.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1459.000000  1459.000000  1459.000000   1459.000000  1459.000000
# mean      1.794380    17.064428     1.744345     58.167923     6.104181
# std      20.207842    56.609763    30.491646    630.806978     2.722432
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     4.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     360.000000   576.000000   800.000000  17000.000000    12.000000
#
#             YrSold
# count  1459.000000
# mean   2007.769705
# std       1.301740
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000
#
# [8 rows x 37 columns]

# %%
dataset.isna().sum().loc[dataset.isna().sum() > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
dataset_test.isna().sum().loc[dataset_test.isna().sum() > 0]
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %% [markdown]
# ### Dealing with missing values

# %%
dataset['LotFrontage'].head()
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# Name: LotFrontage, dtype: float64

# %%
dataset['LotFrontage'] = dataset['LotFrontage'].fillna(dataset['LotFrontage'].mean())
dataset_test['LotFrontage'] = dataset_test['LotFrontage'].fillna(dataset_test['LotFrontage'].mean())

# %%
dataset.groupby('Alley').count()
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# Alley
# Grvl   50          50        50           50       50      50        50
# Pave   41          41        41           41       41      41        41
#
#        LandContour  Utilities  LotConfig    ...      PoolArea  PoolQC  Fence  \
# Alley                                       ...
# Grvl            50         50         50    ...            50       0     14
# Pave            41         41         41    ...            41       0      4
#
#        MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# Alley
# Grvl             4       50      50      50        50             50
# Pave             0       41      41      41        41             41
#
#        SalePrice
# Alley
# Grvl          50
# Pave          41
#
# [2 rows x 80 columns]

# %%
dataset['Alley'].fillna('None', inplace=True)
dataset_test['Alley'].fillna('None', inplace=True)

# %%
print(dataset['MasVnrType'].head())
dataset.groupby('MasVnrType').count()
# Out:
# 0    BrkFace
# 1       None
# 2    BrkFace
# 3       None
# 4    BrkFace
# Name: MasVnrType, dtype: object
#              Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# MasVnrType
# BrkCmn       15          15        15           15       15      15     15
# BrkFace     445         445       445          445      445     445    445
# None        864         864       864          864      864     864    864
# Stone       128         128       128          128      128     128    128
#
#             LotShape  LandContour  Utilities    ...      PoolArea  PoolQC  \
# MasVnrType                                      ...
# BrkCmn            15           15         15    ...            15       0
# BrkFace          445          445        445    ...           445       2
# None             864          864        864    ...           864       4
# Stone            128          128        128    ...           128       1
#
#             Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# MasVnrType
# BrkCmn          7            2       15      15      15        15
# BrkFace        80           11      445     445     445       445
# None          188           40      864     864     864       864
# Stone           6            1      128     128     128       128
#
#             SaleCondition  SalePrice
# MasVnrType
# BrkCmn                 15         15
# BrkFace               445        445
# None                  864        864
# Stone                 128        128
#
# [4 rows x 80 columns]

# %%
dataset['MasVnrType'] = dataset['MasVnrType'].fillna('None')
dataset_test['MasVnrType'] = dataset_test['MasVnrType'].fillna('None')

# %%
dataset.groupby('MasVnrType').count()
# Out:
#              Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# MasVnrType
# BrkCmn       15          15        15           15       15      15     15
# BrkFace     445         445       445          445      445     445    445
# None        872         872       872          872      872     872    872
# Stone       128         128       128          128      128     128    128
#
#             LotShape  LandContour  Utilities    ...      PoolArea  PoolQC  \
# MasVnrType                                      ...
# BrkCmn            15           15         15    ...            15       0
# BrkFace          445          445        445    ...           445       2
# None             872          872        872    ...           872       4
# Stone            128          128        128    ...           128       1
#
#             Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# MasVnrType
# BrkCmn          7            2       15      15      15        15
# BrkFace        80           11      445     445     445       445
# None          188           40      872     872     872       872
# Stone           6            1      128     128     128       128
#
#             SaleCondition  SalePrice
# MasVnrType
# BrkCmn                 15         15
# BrkFace               445        445
# None                  872        872
# Stone                 128        128
#
# [4 rows x 80 columns]

# %%
dataset['MasVnrArea'].head()
# Out:
# 0    196.0
# 1      0.0
# 2    162.0
# 3      0.0
# 4    350.0
# Name: MasVnrArea, dtype: float64

# %%
dataset['MasVnrArea'].fillna(0, inplace=True)
dataset_test['MasVnrArea'].fillna(0, inplace=True)

# %%
dataset.loc[:, ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']].head(20)
# Out:
#    BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 0        Gd       TA           No          GLQ          Unf
# 1        Gd       TA           Gd          ALQ          Unf
# 2        Gd       TA           Mn          GLQ          Unf
# 3        TA       Gd           No          ALQ          Unf
# 4        Gd       TA           Av          GLQ          Unf
# 5        Gd       TA           No          GLQ          Unf
# 6        Ex       TA           Av          GLQ          Unf
# 7        Gd       TA           Mn          ALQ          BLQ
# 8        TA       TA           No          Unf          Unf
# 9        TA       TA           No          GLQ          Unf
# 10       TA       TA           No          Rec          Unf
# 11       Ex       TA           No          GLQ          Unf
# 12       TA       TA           No          ALQ          Unf
# 13       Gd       TA           Av          Unf          Unf
# 14       TA       TA           No          BLQ          Unf
# 15       TA       TA           No          Unf          Unf
# 16       TA       TA           No          ALQ          Unf
# 17      NaN      NaN          NaN          NaN          NaN
# 18       TA       TA           No          GLQ          Unf
# 19       TA       TA           No          LwQ          Unf

# %%
dataset['BsmtQual'].fillna('None', inplace=True)
dataset['BsmtCond'].fillna('None', inplace=True)
dataset['BsmtExposure'].fillna('None', inplace=True)
dataset['BsmtFinType1'].fillna('None', inplace=True)
dataset['BsmtFinType2'].fillna('None', inplace=True)

dataset_test['BsmtQual'].fillna('None', inplace=True)
dataset_test['BsmtCond'].fillna('None', inplace=True)
dataset_test['BsmtExposure'].fillna('None', inplace=True)
dataset_test['BsmtFinType1'].fillna('None', inplace=True)
dataset_test['BsmtFinType2'].fillna('None', inplace=True)

# %%
print(dataset.shape)
print(dataset_test.shape)
# Out:
# (1459, 80)

# %%
dataset = dataset.loc[dataset['Electrical'].isna() == False]
# dataset_test = dataset_test.loc[dataset_test['Electrical'].isna() == False]
print(dataset.shape)
print(dataset_test.shape)
# Out:
# (1459, 81)
# (1459, 80)

# %%
dataset['FireplaceQu'].head(10)
# Out:
# 0    NaN
# 1     TA
# 2     TA
# 3     Gd
# 4     TA
# 5    NaN
# 6     Gd
# 7     TA
# 8     TA
# 9     TA
# Name: FireplaceQu, dtype: object

# %%
dataset['FireplaceQu'].fillna('None', inplace=True)
dataset_test['FireplaceQu'].fillna('None', inplace=True)

# %%
dataset.loc[:, ['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond']].head() # 40
# Out:
#   GarageType  GarageYrBlt GarageFinish GarageQual GarageCond
# 0     Attchd       2003.0          RFn         TA         TA
# 1     Attchd       1976.0          RFn         TA         TA
# 2     Attchd       2001.0          RFn         TA         TA
# 3     Detchd       1998.0          Unf         TA         TA
# 4     Attchd       2000.0          RFn         TA         TA

# %%
dataset['GarageType'].fillna('None', inplace=True)
dataset['GarageYrBlt'].fillna('None', inplace=True)
dataset['GarageFinish'].fillna('None', inplace=True)
dataset['GarageQual'].fillna('None', inplace=True)
dataset['GarageCond'].fillna('None', inplace=True)

dataset_test['GarageType'].fillna('None', inplace=True)
dataset_test['GarageYrBlt'].fillna('None', inplace=True)
dataset_test['GarageFinish'].fillna('None', inplace=True)
dataset_test['GarageQual'].fillna('None', inplace=True)
dataset_test['GarageCond'].fillna('None', inplace=True)

# %%
print(dataset['PoolQC'].unique())
print(dataset['Fence'].unique())
print(dataset['MiscFeature'].unique())
# Out:
# [nan 'Ex' 'Fa' 'Gd']
# [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %%
dataset['PoolQC'].fillna('None', inplace=True)
dataset['Fence'].fillna('None', inplace=True)
dataset['MiscFeature'].fillna('None', inplace=True)

dataset_test['PoolQC'].fillna('None', inplace=True)
dataset_test['Fence'].fillna('None', inplace=True)
dataset_test['MiscFeature'].fillna('None', inplace=True)

# %%
print(dataset.isna().sum().loc[dataset.isna().sum() > 0])
print(dataset_test.isna().sum().loc[dataset_test.isna().sum() > 0])
# Out:
# Series([], dtype: int64)
# MSZoning       4
# Utilities      2
# Exterior1st    1
# Exterior2nd    1
# KitchenQual    1
# Functional     2
# SaleType       1
# dtype: int64

# %%
num_na_cols = list(dataset_test.describe().columns)
for col in num_na_cols:
    dataset_test[col].fillna(0, inplace=True)
cat_na_cols = list(dataset_test.isna().sum().loc[dataset_test.isna().sum() > 0].index)
for col in cat_na_cols:
    dataset_test[col].fillna('None', inplace=True)

# %%
print(dataset_test.isna().sum().loc[dataset_test.isna().sum() > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Outliers!!!
# not today :/

# %% [markdown]
# ### Categorical data & Feature scaling.

# %%
X = dataset.iloc[:, 1:-1]
X_test = dataset_test.iloc[:, 1:]
print(X_test.shape)
print(X.shape)
X.head()
# Out:
# (1459, 79)
# (1459, 79)
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0   None
# 1         Lvl    AllPub       FR2      ...                 0        0   None
# 2         Lvl    AllPub    Inside      ...                 0        0   None
# 3         Lvl    AllPub    Corner      ...                 0        0   None
# 4         Lvl    AllPub       FR2      ...                 0        0   None
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0  None        None       0       2    2008        WD         Normal
# 1  None        None       0       5    2007        WD         Normal
# 2  None        None       0       9    2008        WD         Normal
# 3  None        None       0       2    2006        WD        Abnorml
# 4  None        None       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
y = dataset.iloc[:, [-1]]
print(y.shape)
y.head()
# Out:
# (1459, 1)
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
y_sc = MinMaxScaler()
y = y_sc.fit_transform(y)
y
# Out:
# array([[0.24107763],
#        [0.20358284],
#        [0.26190807],
#        ...,
#        [0.321622  ],
#        [0.14890293],
#        [0.15636717]])

# %%
print(dataset.iloc[0, -1])
print(y_sc.inverse_transform([[0.24107763]]))
# Out:
# 208500
# [[208500.001363]]

# %%
X_sc = MinMaxScaler()
transformed_npa = X_sc.fit_transform(X[list(X.describe().columns)])
transformed_npa_test = X_sc.transform(X_test[list(X_test.describe().columns)])

# %%
X[list(X.describe().columns)].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   ...    GarageArea  \
# 0          2003       196.0         706           0   ...           548
# 1          1976         0.0         978           0   ...           460
# 2          2002       162.0         486           0   ...           608
# 3          1970         0.0         216           0   ...           642
# 4          2000       350.0         655           0   ...           836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#    MiscVal  MoSold  YrSold
# 0        0       2    2008
# 1        0       5    2007
# 2        0       9    2008
# 3        0       2    2006
# 4        0      12    2008
#
# [5 rows x 35 columns]

# %%
X_test[list(X_test.describe().columns)].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   ...    GarageArea  \
# 0          1961         0.0       468.0       144.0   ...         730.0
# 1          1958       108.0       923.0         0.0   ...         312.0
# 2          1998         0.0       791.0         0.0   ...         482.0
# 3          1998        20.0       602.0         0.0   ...         470.0
# 4          1992         0.0       263.0         0.0   ...         506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0         140            0              0          0          120         0
# 1         393           36              0          0            0         0
# 2         212           34              0          0            0         0
# 3         360           36              0          0            0         0
# 4           0           82              0          0          144         0
#
#    MiscVal  MoSold  YrSold
# 0        0       6    2010
# 1    12500       6    2010
# 2        0       3    2010
# 3        0       6    2010
# 4        0       1    2010
#
# [5 rows x 35 columns]

# %%
transformed_df = pd.DataFrame(transformed_npa)
transformed_df.columns = X.describe().columns
X[list(X.describe().columns)] = transformed_df
X[list(X.describe().columns)].head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.235294     0.150685  0.033420     0.666667        0.500   0.949275
# 1    0.000000     0.202055  0.038795     0.555556        0.875   0.753623
# 2    0.235294     0.160959  0.046507     0.666667        0.500   0.934783
# 3    0.294118     0.133562  0.038561     0.666667        0.500   0.311594
# 4    0.235294     0.215753  0.060576     0.777778        0.500   0.927536
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   ...    GarageArea  \
# 0      0.883333     0.12250    0.125089         0.0   ...      0.386460
# 1      0.433333     0.00000    0.173281         0.0   ...      0.324401
# 2      0.866667     0.10125    0.086109         0.0   ...      0.428773
# 3      0.333333     0.00000    0.038271         0.0   ...      0.452750
# 4      0.833333     0.21875    0.116052         0.0   ...      0.589563
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0    0.000000     0.111517       0.000000        0.0          0.0       0.0
# 1    0.347725     0.000000       0.000000        0.0          0.0       0.0
# 2    0.000000     0.076782       0.000000        0.0          0.0       0.0
# 3    0.000000     0.063985       0.492754        0.0          0.0       0.0
# 4    0.224037     0.153565       0.000000        0.0          0.0       0.0
#
#    MiscVal    MoSold  YrSold
# 0      0.0  0.090909    0.50
# 1      0.0  0.363636    0.25
# 2      0.0  0.727273    0.50
# 3      0.0  0.090909    0.00
# 4      0.0  1.000000    0.50
#
# [5 rows x 35 columns]

# %%
transformed_df = pd.DataFrame(transformed_npa_test)
transformed_df.columns = X_test.describe().columns
X_test[list(X_test.describe().columns)] = transformed_df
X_test[list(X_test.describe().columns)].head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.000000     0.202055  0.048246     0.444444        0.625   0.644928
# 1    0.000000     0.205479  0.060609     0.555556        0.625   0.623188
# 2    0.235294     0.181507  0.058566     0.444444        0.500   0.905797
# 3    0.235294     0.195205  0.040562     0.555556        0.625   0.913043
# 4    0.588235     0.075342  0.017318     0.777778        0.500   0.869565
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   ...    GarageArea  \
# 0      0.183333      0.0000    0.082920    0.097693   ...      0.514810
# 1      0.133333      0.0675    0.163536    0.000000   ...      0.220028
# 2      0.800000      0.0000    0.140149    0.000000   ...      0.339915
# 3      0.800000      0.0125    0.106662    0.000000   ...      0.331453
# 4      0.700000      0.0000    0.046598    0.000000   ...      0.356841
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0    0.163361     0.000000            0.0        0.0         0.25       0.0
# 1    0.458576     0.065814            0.0        0.0         0.00       0.0
# 2    0.247375     0.062157            0.0        0.0         0.00       0.0
# 3    0.420070     0.065814            0.0        0.0         0.00       0.0
# 4    0.000000     0.149909            0.0        0.0         0.30       0.0
#
#     MiscVal    MoSold  YrSold
# 0  0.000000  0.454545     1.0
# 1  0.806452  0.454545     1.0
# 2  0.000000  0.181818     1.0
# 3  0.000000  0.454545     1.0
# 4  0.000000  0.000000     1.0
#
# [5 rows x 35 columns]

# %%
print(X.isna().sum().sum())
print(X_test.isna().sum().sum())
# Out:
# 35
# 0

# %%
X = X.iloc[:-1, :]
X.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 1454    0.235294       FV     0.140411  0.030929   Pave  Pave      Reg
# 1455    0.000000       RL     0.219178  0.055505   Pave  None      Reg
# 1456    0.294118       RL     0.154110  0.036187   Pave  None      Reg
# 1457    0.000000       RL     0.160959  0.039342   Pave  None      Reg
# 1458    0.000000       RL     0.184932  0.040370   Pave  None      Reg
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# 1454         Lvl    AllPub    Inside      ...               0.0      0.0
# 1455         Lvl    AllPub    Inside      ...               0.0      0.0
# 1456         Lvl    AllPub    Inside      ...               0.0      0.0
# 1457         Lvl    AllPub    Inside      ...               0.0      0.0
# 1458         Lvl    AllPub    Inside      ...               0.0      0.0
#
#      PoolQC  Fence MiscFeature  MiscVal    MoSold  YrSold  SaleType  \
# 1454   None   None        None  0.00000  0.636364    0.25        WD
# 1455   None   None        None  0.00000  0.090909    1.00        WD
# 1456   None  MnPrv        None  0.16129  0.363636    1.00        WD
# 1457   None  GdPrv        Shed  0.00000  0.272727    1.00        WD
# 1458   None   None        None  0.00000  0.454545    0.50        WD
#
#       SaleCondition
# 1454         Normal
# 1455         Normal
# 1456         Normal
# 1457         Normal
# 1458         Normal
#
# [5 rows x 79 columns]

# %%
print(X.isna().sum().sum())
print(X_test.isna().sum().sum())
# Out:
# 0
# 0

# %%
y = y[:-1, :]

# %%
X = pd.get_dummies(X)
X_test = pd.get_dummies(X_test)

# %%
print(X.shape)
print(X_test.shape)
print(y.shape)
# Out:
# (1458, 399)
# (1459, 388)
# (1458, 1)

# %% [markdown]
# ### Our first model

# %%
# Splitting the data: 75% training, 25% testing
X_train, X_validation, y_train, y_validation = train_test_split(X.values, y, test_size=0.25)

# %%
print(X_train.shape)
print(X_validation.shape)
print(y_train.shape)
print(y_validation.shape)
# Out:
# (1093, 399)
# (365, 399)
# (1093, 1)
# (365, 1)

# %%
# fit model no training data
model = XGBRegressor()
history = model.fit(X_train, y_train)

# %%
y_predicted = model.predict(X_validation)

# %%
score = mean_squared_error(y_validation, y_predicted)
score**0.5
# Out:
# 0.04607321534903408

# %% [markdown]
# ### Feature Engineering!!

# %% [markdown]
# ### Retraining and hyperparameter tuning

# %%
scores = []
combinations = list(itertools.product([.03, .05, .07], [5, 6, 7], [500, 1000]))
combinations
# Out:
# [(0.03, 5, 500),
#  (0.03, 5, 1000),
#  (0.03, 6, 500),
#  (0.03, 6, 1000),
#  (0.03, 7, 500),
#  (0.03, 7, 1000),
#  (0.05, 5, 500),
#  (0.05, 5, 1000),
#  (0.05, 6, 500),
#  (0.05, 6, 1000),
#  (0.05, 7, 500),
#  (0.05, 7, 1000),
#  (0.07, 5, 500),
#  (0.07, 5, 1000),
#  (0.07, 6, 500),
#  (0.07, 6, 1000),
#  (0.07, 7, 500),
#  (0.07, 7, 1000)]

# %%
for combo in combinations:
    model = XGBRegressor(nthread=4, objective='reg:linear', learning_rate=combo[0], max_depth=combo[1], min_child_weight=4,
                        silent=1, subsample=0.7, colsample_bytree=0.7, n_estimators=combo[2])
    model.fit(X_train, y_train)
    y_predicted = model.predict(X_validation)
    score = mean_squared_error(y_validation, y_predicted)**0.5
    print('lr: {}, max_depth: {} => {}'.format(combo[0], combo[1], score))
# Out:
# lr: 0.03, max_depth: 5 => 0.03855245415737211
# lr: 0.03, max_depth: 5 => 0.03780598419377251
# lr: 0.03, max_depth: 6 => 0.03872154629437868
# lr: 0.03, max_depth: 6 => 0.03817625404920664
# lr: 0.03, max_depth: 7 => 0.039277684391009586
# lr: 0.03, max_depth: 7 => 0.03913373477251434
# lr: 0.05, max_depth: 5 => 0.0394820528518792
# lr: 0.05, max_depth: 5 => 0.03929968202725975
# lr: 0.05, max_depth: 6 => 0.03826546701338355
# lr: 0.05, max_depth: 6 => 0.038242484052928405
# lr: 0.05, max_depth: 7 => 0.03890175523879284
# lr: 0.05, max_depth: 7 => 0.038904384193170424
# lr: 0.07, max_depth: 5 => 0.03906720350224608
# lr: 0.07, max_depth: 5 => 0.03903894258134248
# lr: 0.07, max_depth: 6 => 0.038917250635941786
# lr: 0.07, max_depth: 6 => 0.03892124084728805
# lr: 0.07, max_depth: 7 => 0.03884072000540773
# lr: 0.07, max_depth: 7 => 0.03882935931634577

# %% [markdown]
# ### Now what !
